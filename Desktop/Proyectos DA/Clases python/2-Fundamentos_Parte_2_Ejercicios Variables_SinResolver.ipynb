# %% [markdown]
# # Ejercicios de Tipos de Datos Simples

# %% [markdown]
# ### Ejercicio 1
# Escribir un programa que muestre por pantalla la cadena con tu nombre.

# %% [markdown]
# ### Ejercicio 2
# Escribir un programa que almacene la cadena **'Hoy me he levantado feliz'** a variable llamada mensaje y luego muestre por pantalla el contenido de dicha variable.

# %% [markdown]
# ### Ejercicio 3
# Escribir un programa que pregunte el nombre del usuario en la consola y después pregunte por su primer apellio.
# Cuando el usuario lo introduzca muestre por pantalla la cadena: Hola "nombre" "apellido", ¿en qué puedo ayudarte?, donde "nombre" y "apellido" es el dato que el usuario ha introducido.

# %% [markdown]
# ### Ejercicio 4
# Escribir un programa que muestre por pantalla el resultado de la siguiente operación aritmética.
# \begin{align*}
# C= (\frac{3+2}{2*5})^2
# \end{align*}

# %% [markdown]
# ### Ejercicio 5
# Escribir un programa que pregunte al usuario por el número de horas trabajadas y el coste por hora. Después debe mostrar por pantalla el dinero que le corresponde.

# %% [markdown]
# ### Ejercicio 6
# Escribir un programa que la variable dividendo sea 27, la variable divisor sea 4 y mostrar por pantalla cuanto sería el cociente y cuanto el resto.

# %% [markdown]
# ### Ejercicio 7
#
# Una juguetería tiene mucho éxito en dos de sus productos: payasos y muñecas. Suele hacer venta por correo y la empresa de logística les cobra por peso de cada paquete así que deben calcular el peso de los payasos y muñecas que saldrán en cada paquete a demanda. Cada payaso pesa 112 g y cada muñeca 75 g. Escribir un programa que lea el número de payasos y muñecas vendidos en el último pedido y calcule el peso total del paquete que será enviado.

# %% [markdown]
# ### Ejercicio 8
#
# Imagina que acabas de abrir una nueva cuenta de ahorros que te ofrece el 4% de interés al año. Estos ahorros debido a intereses, que no se cobran hasta finales de año, se te añaden al balance final de tu cuenta de ahorros. Escribir un programa que comience leyendo la cantidad de dinero depositada en la cuenta de ahorros, introducida por el usuario. Después el programa debe calcular y mostrar por pantalla la cantidad de ahorros tras el primer, segundo y tercer años. Redondear cada cantidad a dos decimales.

# %% [markdown]
# ### Ejercicio 9
#
# Una panadería vende barras de pan a 3.49€ cada una. El pan que no es del día tiene un descuento del 60%. Escribir un programa que comience leyendo el número de barras vendidas que no son del día. Después el programa debe mostrar el precio habitual de una barra de pan, el descuento que se le hace por no ser fresca y el coste final total.

# %% [markdown]
# ### Ejercicio 10
# Calculo de la superficie de un cuadrado conociendo uno de sus lados.
# El valor de será de 6 cm.
# Debemos calcular la superficie de dicho cuadrado (lado * lado)
# y por pantalla nos tendrá que aparecer el mensaje de: La superficie del cuadrado es ...

# %% [markdown]
# ### Ejercicio 11
#
# Leer por teclado dos numeros y calcular la suma y multiplicacion de los mismos.
#
# Mostrar los resultados por pantalla

# %% [markdown]
# ### Ejercicio 12
#
# Tenemos en un almacén una cierta cantidad de producto que queremos saber cuanto en total debemos pagar por ella. Si conocemos que dicha cantidad es de 150 unidades y que el precio por unidad es de 20 €.
# Mostrar un menseje de: La cantidad a pagar por x productos a un precio de x es de x.

# %% [markdown]
# ### Ejercicio 13
#
# Calcular el sueldo mensual de un operario conociendo la cantidad de horas trabajadas y el valor por hora.
